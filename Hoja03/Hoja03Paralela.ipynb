# %%
# !ls /usr/local
# Out:
# bin  colab  cuda  cuda-12  cuda-12.2  etc  games  include  lib	lib64  man  opt  sbin  share  src

# %%
# !which nvcc
# Out:
# /usr/local/cuda/bin/nvcc

# %%
# !nvidia-smi
# Out:
# Tue Nov  5 21:06:29 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !nvcc -arch=sm_50 -gencode=arch=compute_50,code=sm_50 hello.cu -o hello
# Out:
# hello.cu: In function ‘int main()’:
# hello.cu:22:22: warning: ‘cudaError_t cudaThreadSynchronize()’ is deprecated [-Wdeprecated-declarations]
#    22 |   cudaThreadSynchronize(); //deprecated
#       |   ~~~~~~~~~~~~~~~~~~~^~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cuda_runtime_api.h:1069:46: note: declared here
#  1069 | extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#       |                                              ^~~~~~~~~~~~~~~~~~~~~

# %%
# !./hello
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world

# %%
# !nvcc -arch=sm_50 -gencode=arch=compute_50,code=sm_50 hello1.3.cu -o hello3

# %%
# !./hello3
# Out:
# Hello world from thread 1984, Name: Abner Garcia, Carnet: 21285
# Hello world from thread 1985, Name: Abner Garcia, Carnet: 21285
# Hello world from thread 1986, Name: Abner Garcia, Carnet: 21285
# Hello world from thread 1987, Name: Abner Garcia, Carnet: 21285
# Hello world from thread 1988, Name: Abner Garcia, Carnet: 21285
# Hello world from thread 1989, Name: Abner Garcia, Carnet: 21285
# Hello world from thread 1990, Name: Abner Garcia, Carnet: 21285
# Hello world from thread 1991, Name: Abner Garcia, Carnet: 21285
# Hello world from thread 1992, Name: Abner Garcia, Carnet: 21285
# Hello world from thread 1993, Name: Abner Garcia, Carnet: 21285
# Hello world from thread 1994, Name: Abner Garcia, Carnet: 21285
# Hello world from thread 1995, Name: Abner Garcia, Carnet: 21285
# Hello world from thread 1996, Name: Abner Garcia, Carnet: 21285
# Hello world from thread 1997, Name: Abner Garcia, Carnet: 21285
# Hello world from thread 1998, Name: Abner Garcia, Carnet: 21285
# ...

# %%
# !nvcc -arch=sm_50 -gencode=arch=compute_50,code=sm_50 hello.1.5.cu -o hello5

# %%
# !./hello5

# %% [markdown]
# ### Ejercicio 2

# %%
# !nvcc -arch=sm_50 -gencode=arch=compute_50,code=sm_50 hello2.cu -o hello2
# Out:
# hello2.cu: In function ‘int main()’:
# hello2.cu:38:22: warning: ‘cudaError_t cudaThreadSynchronize()’ is deprecated [-Wdeprecated-declarations]
#    38 |   cudaThreadSynchronize ();
#       |   ~~~~~~~~~~~~~~~~~~~^~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cuda_runtime_api.h:1069:46: note: declared here
#  1069 | extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#       |                                              ^~~~~~~~~~~~~~~~~~~~~

# %%
# !./hello2
# Out:
# Hello world from 220
# Hello world from 221
# Hello world from 222
# Hello world from 223
# Hello world from 224
# Hello world from 225
# Hello world from 226
# Hello world from 227
# Hello world from 228
# Hello world from 229
# Hello world from 120
# Hello world from 121
# Hello world from 122
# Hello world from 123
# Hello world from 124
# Hello world from 125
# Hello world from 126
# Hello world from 127
# Hello world from 128
# Hello world from 129
# Hello world from 20
# Hello world from 21
# Hello world from 22
# Hello world from 23
# Hello world from 24
# Hello world from 25
# Hello world from 26
# Hello world from 27
# Hello world from 28
# Hello world from 29
# Hello world from 170
# Hello world from 171
# Hello world from 172
# Hello world from 173
# Hello world from 174
# Hello world from 175
# Hello world from 176
# Hello world from 177
# Hello world from 178
# Hello world from 179
# Hello world from 70
# Hello world from 71
# Hello world from 72
# Hello world from 73
# ...

# %%
# !nvcc -arch=sm_50 -gencode=arch=compute_50,code=sm_50 hello2.1.cu -o hello2.2

# %%
# !./hello2.2
# Out:
# Hello world from 3936 by Abner Garcia - 21285
# Hello world from 3937 by Abner Garcia - 21285
# Hello world from 3938 by Abner Garcia - 21285
# Hello world from 3939 by Abner Garcia - 21285
# Hello world from 3940 by Abner Garcia - 21285
# Hello world from 3941 by Abner Garcia - 21285
# Hello world from 3942 by Abner Garcia - 21285
# Hello world from 3943 by Abner Garcia - 21285
# Hello world from 3944 by Abner Garcia - 21285
# Hello world from 3945 by Abner Garcia - 21285
# Hello world from 3946 by Abner Garcia - 21285
# Hello world from 3947 by Abner Garcia - 21285
# Hello world from 3948 by Abner Garcia - 21285
# Hello world from 3949 by Abner Garcia - 21285
# Hello world from 3950 by Abner Garcia - 21285
# Hello world from 3951 by Abner Garcia - 21285
# Hello world from 3952 by Abner Garcia - 21285
# Hello world from 3953 by Abner Garcia - 21285
# Hello world from 3954 by Abner Garcia - 21285
# Hello world from 3955 by Abner Garcia - 21285
# ...

# %%
# !nvcc -arch=sm_50 -gencode=arch=compute_50,code=sm_50 hello2.2.cu -o hello2.3

# %%
# !./hello2.3
# Out:
# Max Threads Per Block (x): 1024
# Max Threads Per Block (y): 1024
# Max Threads Per Block (z): 64
# Max Blocks Per Grid (x): 2147483647
# Max Blocks Per Grid (y): 65535
# Max Blocks Per Grid (z): 65535
# Hello world from 100351 by Abner Garcia - 21285
